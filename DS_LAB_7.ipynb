# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanth422/DATA-SCIENCE-LAB/blob/main/DS_LAB_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SIVAJI PRASHNATH
# 23102A010375
# # =====================================================
# DATA SCIENCE - PROGRAM 7
# TOPIC: DATA AGGREGATION
# =====================================================

# %%
# -----------------------------------------------------
# Create a DataFrame
# -----------------------------------------------------
# A DataFrame is a two-dimensional table.
#
# Category Column:
# A
# A
# B
# B
#
# Data Column:
# 10
# 20
# 30
# 40

# %%
import pandas as pd

# Each value in Category corresponds to a value in Data.
df = pd.DataFrame({
    'Category': ['A', 'A', 'B', 'B'],
    'Data': [10, 20, 30, 40]
})

# %%
# -----------------------------------------------------
# Display Original Data
# -----------------------------------------------------
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#   Category  Data
# 0        A    10
# 1        A    20
# 2        B    30
# 3        B    40

# %%
# -----------------------------------------------------
# GroupBy Operation
# -----------------------------------------------------
# groupby() groups rows having the same Category value.
#
# Group A -> [10, 20]
# Group B -> [30, 40]
grouped = df.groupby('Category')

# %%
# -----------------------------------------------------
# Sum Aggregation
# -----------------------------------------------------
# Select the Data column from each group.
# sum() calculates the total value for every group.
#
# A = 10 + 20 = 30
# B = 30 + 40 = 70
print("\nSum of Data by Category:")
print(grouped['Data'].sum())
# Out:
# Sum of Data by Category:
# Category
# A    30
# B    70
# Name: Data, dtype: int64

# %%
# -----------------------------------------------------
# Multiple Aggregations
# -----------------------------------------------------
# agg() allows multiple statistical operations.
#
# mean = average value
# std  = standard deviation
#
# Category A:
# mean = (10 + 20)/2 = 15
#
# Category B:
# mean = (30 + 40)/2 = 35
print("\nMean and Standard Deviation:")
print(grouped['Data'].agg(['mean', 'std']))
# Out:
# Mean and Standard Deviation:
#           mean       std
# Category
# A         15.0  7.071068
# B         35.0  7.071068
